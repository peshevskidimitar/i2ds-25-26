# %%
import pandas as pd
import seaborn as sns
import missingno as msno
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import cross_val_score, train_test_split
import xgboost as xgb
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/other/real_estate_dataset_mk_missing.csv')

# %%
df.head()
# Out:
#      city  area_sq_meters  num_rooms  floor  year_built  \
# 0     NaN            80.0        4.0    5.0      2009.0
# 1  Skopje            92.1        5.0    3.0      2008.0
# 2  Skopje            97.4        5.0    0.0      2002.0
# 3  Skopje            49.5        3.0    5.0      2024.0
# 4  Skopje             NaN        3.0    2.0         NaN
#
#    distance_from_center_km     price
# 0                     3.55  150804.0
# 1                     3.54  178480.0
# 2                     2.41  168418.0
# 3                     3.97   90170.0
# 4                     3.75   77454.0

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True,)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# city                        85
# area_sq_meters              92
# num_rooms                   86
# floor                      110
# year_built                  98
# distance_from_center_km     72
# price                       95
# dtype: int64

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df['city'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='city'>

# %%
cities = pd.get_dummies(df['city'], prefix='city')
df = pd.concat([df, cities], axis=1)
df.drop(columns=['city'], inplace=True)

# %%
df.isnull().sum()
# Out:
# area_sq_meters              89
# num_rooms                   78
# floor                      108
# year_built                  93
# distance_from_center_km     65
# price                        0
# city_Bitola                  0
# city_Ohrid                   0
# city_Prilep                  0
# city_Skopje                  0
# city_Tetovo                  0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %%
iterative_imputer = IterativeImputer()
df[["area_sq_meters", "num_rooms"]]= iterative_imputer.fit_transform(df[["area_sq_meters", "num_rooms"]])

# %%
df.isnull().sum()
# Out:
# area_sq_meters               0
# num_rooms                    0
# floor                      108
# year_built                  93
# distance_from_center_km     65
# price                        0
# city_Bitola                  0
# city_Ohrid                   0
# city_Prilep                  0
# city_Skopje                  0
# city_Tetovo                  0
# dtype: int64

# %%
df['floor'].hist()
# Out:
# <Axes: >

# %%
df['year_built'].hist()
# Out:
# <Axes: >

# %%
df['distance_from_center_km'].hist()
# Out:
# <Axes: >

# %%
df.drop(columns=['floor'], inplace=True)
df['year_built'] = df['year_built'].fillna(df['year_built'].median())
df['distance_from_center_km'] = df['distance_from_center_km'].fillna(df['distance_from_center_km'].median())

# %%
df.isnull().sum()
# Out:
# area_sq_meters             0
# num_rooms                  0
# year_built                 0
# distance_from_center_km    0
# price                      0
# city_Bitola                0
# city_Ohrid                 0
# city_Prilep                0
# city_Skopje                0
# city_Tetovo                0
# dtype: int64

# %%
df.head()
# Out:
#    area_sq_meters  num_rooms  year_built  distance_from_center_km     price  \
# 0       80.000000        4.0      2009.0                     3.55  150804.0
# 1       92.100000        5.0      2008.0                     3.54  178480.0
# 2       97.400000        5.0      2002.0                     2.41  168418.0
# 3       49.500000        3.0      2024.0                     3.97   90170.0
# 4       62.580859        3.0      2005.0                     3.75   77454.0
#
#    city_Bitola  city_Ohrid  city_Prilep  city_Skopje  city_Tetovo
# 0        False       False        False        False        False
# 1        False       False        False         True        False
# 2        False       False        False         True        False
# 3        False       False        False         True        False
# 4        False       False        False         True        False

# %%
X = df.drop(columns=["price"])
y = df["price"]

model = xgb.XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
)

cv_scores = cross_val_score(model, X, y, cv=5, scoring="r2")

print("Cross-validation R² scores:", cv_scores)
print("Mean R²:", cv_scores.mean())
print("Std of R²:", cv_scores.std())
# Out:
# Cross-validation R² scores: [0.87159684 0.89620477 0.92131    0.89740957 0.95322567]
# Mean R²: 0.9079493682477594
# Std of R²: 0.027564392518101263

# %%
X, y = df.drop(columns='price'), df['price']
X_train, X_test, y_train, y_test = train_test_split(X,y)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)

print(f"R²:   {r2:.4f}")
print(f"MAE:  {mae:,.2f}")
print(f"MSE: {rmse:,.2f}")
# Out:
# R²:   0.9194
# MAE:  8,631.90
# MSE: 150,695,249.19

# %%
feature_importance = model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({'Feature': list(feature_importance.keys()), 'F-score': list(feature_importance.values())})
importance_df = importance_df.sort_values(by='F-score', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['F-score'])
plt.xlabel("F-score (Frequency)")
plt.ylabel("Feature")
plt.title("XGBoost Feature Importance (F-score)")
plt.gca().invert_yaxis()
